# %% [markdown]
# # Amazon Bedrock Guardrails Exercise
#
# This notebook was reconstructed from an Edge `.mhtml` export of a Coursera exercise. Some formatting may have been simplified during conversion.

# %% [markdown]
# ## Exercise overview
#
# The exercises in this course will have an associated charge in your AWS account. In this exercise, you will create the following resources: Amazon Bedrock The final task in this exercise includes instructions to delete all the resources that you create. Familiarize yourself with Amazon Bedrock pricing Opens in a new tab &nbsp;and the&nbsp; AWS Free Tier Opens in a new tab . Exercise Overview In this exercise, you’ll use Amazon Bedrock APIs to: ✅ Create an inference profile to enable interaction with a Bedrock model that doesn't support on-demand usage. ✅ Define a custom Guardrail to filter harmful content, prompt attacks, and restricted topics. ✅ Enforce grounding and relevance checks to prevent unverified or misleading responses. ✅ Detect and block prompt injection attacks and inappropriate user queries. ✅ Customize Guardrails by defining and testing your own blocked topics.

# %% [markdown]
# ## Prerequisites
#
# Before you start, you need to have: Python 3.x AWS CLI configured with AWS credentials (aws configure) If you do not have Python installed and AWS credentials configured, return to exercise 1 to install needed prerequisites. Task 1: Creating an Exercise Environment To begin this exercise, you'll need to create a new Python environment and install the needed packages for the upcoming steps. Run the command that corresponds to your operating system: Windows Open the&nbsp; Terminal &nbsp;application and run the following command: cd ~/Desktop; python −m venv exercise3;&nbsp;.\exercise4\Scripts\Activate.ps1; pip install boto3 jupyter Verify that a folder named&nbsp; exercise3 &nbsp;was created on your desktop. MacOS Open the&nbsp; Terminal &nbsp;application and run the following command: cd ~/Desktop &amp;&amp; python3 -m venv exercise3 &amp;&amp; source exercise3/bin/activate &amp;&amp; pip install boto3 jupyter Verify that a folder named&nbsp; exercise3 &nbsp;was created on your desktop. This step creates a new Python environment to use during this exercise.

# %%
import boto3
session = boto3.Session()
sts = session.client('sts')
print('AWS account:', sts.get_caller_identity()['Account'])

# %% [markdown]
# ## Create inference profile
#
# In this task, you'll use the Bedrock Guardrail to stop Bedrock from processing personally identifiable information (PII). First, create a new Jupyter notebook. Open the&nbsp; Terminal &nbsp;application and run the following command: jupyter notebook In the&nbsp; Jupyter &nbsp;window, select&nbsp; File ,&nbsp; New , and then&nbsp; Notebook . Select&nbsp; Untitled1 &nbsp;and enter&nbsp; genai-exercise3-guardrail.ipynb &nbsp;as the name for your newly created notebook. Choose&nbsp; Rename . Next, run the following Python code to test how Amazon Bedrock Guardrail blocks the PII. 22 19 20 21 16 17 18 14 15 11 12 13 6 7 8 9 10 3 4 5 1 2 JSON ( response ) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; }, &nbsp;&nbsp;&nbsp;&nbsp; ] &nbsp;&nbsp;&nbsp;&nbsp; ) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 'text' : &nbsp; { &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 'text' : &nbsp; 'The&nbsp;license&nbsp;plate&nbsp;in&nbsp;the&nbsp;picture&nbsp;is&nbsp;UNV&nbsp;425.' , &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; }, &nbsp;&nbsp;&nbsp;&nbsp;content= [ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; { &nbsp;&nbsp;&nbsp;&nbsp;guardrailIdentifier=GUARDRAIL_ID , &nbsp;&nbsp;&nbsp;&nbsp;guardrailVersion= 'DRAFT' , &nbsp;&nbsp;&nbsp;&nbsp;source= 'OUTPUT' , GUARDRAIL_ID&nbsp;=&nbsp; "INSERT&nbsp;GUARDRAIL&nbsp;ID&nbsp;HERE" &nbsp; bedrock&nbsp;=&nbsp;boto3.client ( service_name= 'bedrock-runtime' , &nbsp;region_name= 'us-east-1' ) &nbsp; response&nbsp;=&nbsp;bedrock.apply_guardrail ( import &nbsp;json &nbsp; MODEL_ID&nbsp;=&nbsp; "INSERT&nbsp;INFERENCE&nbsp;PROFILE&nbsp;ARN&nbsp;HERE" import &nbsp;boto3 from &nbsp;IPython.display&nbsp; import &nbsp;JSON Enter to Rename, Shift+E

# %%
cmd = [
    'aws','bedrock','create-inference-profile',
    '--region','us-east-1',
    '--inference-profile-name','exercise3-inference-profile',
    '--model-source','{"copyFrom": "arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-micro-v1:0"}'
]
print('Run manually if needed:')
print(' '.join(cmd))

# %% [markdown]
# ## Create the guardrail in the console
#
# Create a guardrail in the Bedrock console, enable harmful content and prompt attack filters, add a denied topic, enable profanity and PII filtering, and record the Guardrail ID.

# %% [markdown]
# ## Test the guardrail
#
# Create a new notebook section to test how the guardrail blocks PII and unsafe prompts.

# %%
guardrail_id = 'REPLACE_WITH_GUARDRAIL_ID'
guardrail_version = 'DRAFT'
region = 'us-east-1'
prompt = 'My license plate is ABC-1234. Can you store it?'
print({'guardrail_id': guardrail_id, 'guardrail_version': guardrail_version, 'region': region, 'prompt': prompt})

# %% [markdown]
# ## Notes
#
# - Review the original MHTML if any exact step text is missing.
# - The conversion preserves the workflow, but not every embedded UI screenshot or page style.
