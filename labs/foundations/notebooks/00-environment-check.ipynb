# %% [markdown]
# # Runbook Labs Intro
#
# This notebook verifies that your GitHub Codespaces + Jupyter environment is working.

# %%
import sys
print(sys.version)

# %%
import pandas as pd
df = pd.DataFrame([
    {"step": 1, "task": "Open Codespace", "status": "done"},
    {"step": 2, "task": "Load notebook", "status": "done"},
    {"step": 3, "task": "Run cells", "status": "ready"}
])
df

# %% [markdown]
# ## Next steps
#
# - Add your own runbook scenario notebooks
# - Add sample data in `data/`
# - Add helper scripts in `scripts/`
