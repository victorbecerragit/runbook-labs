# %% [markdown]
# # Lab Template
#
# Use this notebook as a base for a new runbook lab.

# %% [markdown]
# ## Scenario
# Describe the incident, operational issue, or troubleshooting case here.

# %% [markdown]
# ## Objectives
#
# - Identify the issue
# - Collect evidence
# - Propose remediation
# - Document findings

# %%
# Load data, call APIs, or inspect logs here

# %% [markdown]
# ## Observations
# Write down what the learner should notice.

# %% [markdown]
# ## Remediation
# Document the expected next action or fix.
