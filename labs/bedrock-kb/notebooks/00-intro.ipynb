# %% [markdown]
# # Bedrock KB: Introduction\n\n**Objective**: Understand the managed Bedrock KB offering.\n\n## Setup\nRun the cell below to load dependencies.

# %%
import sys\nsys.path.append('../../shared/python')\nprint('Setup complete.')

# %% [markdown]
# ## Execution\n\nAdd your lab logic here.

# %%
# TODO: Implement lab step

# %% [markdown]
# ## Next Steps\n\nReview the outputs and proceed to the next notebook.
